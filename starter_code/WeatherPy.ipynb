# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import api_keys
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

#City for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # Replace spaces with %20 to create url correctly 
    city = city.replace(" ", "%20")
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:

        cities.append(city)

# Print the city count to confirm count
len(cities)
# Out:
# 642

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = api_keys.weather_api_key
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter 
        record= record + 1
        
        # Wait in loop to not over exceed rate limit of API
        time.sleep(0.025)
        
    # If no record found skip to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=upernavik
# Processing Record 2 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=albany
# City not found. Skipping...
# Processing Record 3 | Palana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=palana
# Processing Record 4 | George Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=georgetown
# Processing Record 5 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=busselton
# Processing Record 6 | Ko Samui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ko%20samui
# Processing Record 7 | Luangwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=luangwa
# Processing Record 8 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=saint-philippe
# Processing Record 9 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=manokwari
# Processing Record 10 | Tigre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tigre
# Processing Record 11 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=narsaq
# Processing Record 12 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=alofi
# Processing Record 13 | Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=nelson%20bay
# Processing Record 14 | Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=thinadhoo
# Processing Record 15 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=lebu
# Processing Record 16 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=jamestown
# Processing Record 17 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=puerto%20ayora
# Processing Record 18 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=los%20llanos%20de%20aridane
# Processing Record 19 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=rikitea
# Processing Record 20 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=talnakh
# City not found. Skipping...
# Processing Record 21 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=mataura
# City not found. Skipping...
# Processing Record 22 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=new%20norfolk
# Processing Record 23 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bluff
# Processing Record 24 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=esperance
# Processing Record 25 | Hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=hirara
# Processing Record 26 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=thompson
# Processing Record 27 | Manggar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=manggar
# Processing Record 28 | Harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=harper
# Processing Record 29 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kapaa
# Processing Record 30 | Trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=trairi
# Processing Record 31 | Atbasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=atbasar
# City not found. Skipping...
# Processing Record 32 | Ghanzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ghanzi
# Processing Record 33 | Martapura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=martapura
# City not found. Skipping...
# Processing Record 34 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bambous%20virieux
# Processing Record 35 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bathsheba
# Processing Record 36 | Khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=khandyga
# Processing Record 37 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=punta%20arenas
# Processing Record 38 | Kem'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kem
# Processing Record 39 | Murdochville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=murdochville
# Processing Record 40 | Limoeiro do Ajuru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=limoeiro%20do%20ajuru
# Processing Record 41 | Wilmington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=wilmington
# Processing Record 42 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=castro
# Processing Record 43 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kavieng
# Processing Record 44 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=vaini
# Processing Record 45 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=airai
# Processing Record 46 | Murgab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=murgab
# Processing Record 47 | Broken Hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=broken%20hill
# Processing Record 48 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=petropavlovsk-kamchatskiy
# Processing Record 49 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=saskylakh
# Processing Record 50 | Jaumave
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=jaumave
# Processing Record 51 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=dikson
# Processing Record 52 | Haicheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=haicheng
# Processing Record 53 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kahului
# Processing Record 54 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=torbay
# Processing Record 55 | Wakkanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=wakkanai
# City not found. Skipping...
# Processing Record 56 | Limbang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=limbang
# Processing Record 57 | Zonguldak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=zonguldak
# Processing Record 58 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=port%20alfred
# Processing Record 59 | Ariquemes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ariquemes
# Processing Record 60 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=butaritari
# Processing Record 61 | Gukovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=gukovo
# Processing Record 62 | Mishelevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=mishelevka
# Processing Record 63 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=hobart
# Processing Record 64 | Irbeyskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=irbeyskoye
# Processing Record 65 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kieta
# Processing Record 66 | Palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=palmer
# Processing Record 67 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bredasdorp
# Processing Record 68 | Shakhtinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=shakhtinsk
# Processing Record 69 | Altamirano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=altamirano
# Processing Record 70 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=mar%20del%20plata
# Processing Record 71 | Ollon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ollon
# Processing Record 72 | Oranjestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=oranjestad
# Processing Record 73 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=cidreira
# Processing Record 74 | Sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=sobolevo
# Processing Record 75 | Severo-Kuril'sk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=severo-kurilsk
# Processing Record 76 | Kovdor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kovdor
# Processing Record 77 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=port%20elizabeth
# Processing Record 78 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=barrow
# Processing Record 79 | Kamina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kamina
# Processing Record 80 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ahipara
# Processing Record 81 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=brae
# Processing Record 82 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ushuaia
# Processing Record 83 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=avarua
# Processing Record 84 | Baoshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=baoshan
# City not found. Skipping...
# Processing Record 85 | Gualaquiza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=gualaquiza
# Processing Record 86 | Lüderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=luderitz
# Processing Record 87 | Rincon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=rincon
# Processing Record 88 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=aklavik
# Processing Record 89 | Mahajanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=mahajanga
# Processing Record 90 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=saldanha
# Processing Record 91 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=coquimbo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 92 | Boussé
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bousse
# Processing Record 93 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=hermanus
# Processing Record 94 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=saint%20george
# Processing Record 95 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=guerrero%20negro
# Processing Record 96 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=nikolskoye
# Processing Record 97 | Tsuyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tsuyama
# Processing Record 98 | Catherinas Lust
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=fort%20wellington
# Processing Record 99 | Bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bengkulu
# City not found. Skipping...
# Processing Record 100 | Erchie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=erchie
# Processing Record 101 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=atuona
# Processing Record 102 | Carauari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=carauari
# City not found. Skipping...
# Processing Record 103 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=waingapu
# Processing Record 104 | Hue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=hue
# Processing Record 105 | Missoula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=missoula
# Processing Record 106 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=hilo
# Processing Record 107 | São Sebastião do Caí
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=sao%20sebastiao%20do%20cai
# Processing Record 108 | Dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=dudinka
# Processing Record 109 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=hithadhoo
# Processing Record 110 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=katsuura
# Processing Record 111 | Bluefield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bluefield
# City not found. Skipping...
# Processing Record 112 | Goianápolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=goianapolis
# Processing Record 113 | Buraidah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=buraydah
# Processing Record 114 | Kaspiysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kaspiysk
# Processing Record 115 | Mahébourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=mahebourg
# Processing Record 116 | Pechenga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=pechenga
# Processing Record 117 | Kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kloulklubed
# City not found. Skipping...
# Processing Record 118 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=souillac
# Processing Record 119 | Saint Paul Harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kodiak
# Processing Record 120 | Ellisras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ellisras
# City not found. Skipping...
# Processing Record 121 | Udomlya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=udomlya
# Processing Record 122 | Mandalī
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=mandali
# Processing Record 123 | Minsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=minsk
# Processing Record 124 | Mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=mitsamiouli
# Processing Record 125 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=hofn
# Processing Record 126 | São Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=sao%20filipe
# Processing Record 127 | Atoyac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=atoyac
# Processing Record 128 | Acarí
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=acari
# Processing Record 129 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=sola
# Processing Record 130 | Najrān
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=najran
# Processing Record 131 | Chui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=chuy
# Processing Record 132 | Colares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=colares
# Processing Record 133 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=haines%20junction
# Processing Record 134 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ribeira%20grande
# Processing Record 135 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=cape%20town
# Processing Record 136 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=lavrentiya
# Processing Record 137 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kaitangata
# Processing Record 138 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tuktoyaktuk
# Processing Record 139 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=norman%20wells
# Processing Record 140 | Cap Malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=cap%20malheureux
# Processing Record 141 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=hualmay
# Processing Record 142 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=codrington
# Processing Record 143 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=nome
# Processing Record 144 | Dongobesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=dongobesh
# Processing Record 145 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=qaanaaq
# Processing Record 146 | Dinahican
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=dinahican
# Processing Record 147 | Manzanillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=manzanillo
# Processing Record 148 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=labuhan
# Processing Record 149 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ponta%20do%20sol
# Processing Record 150 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=yellowknife
# Processing Record 151 | Coyhaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=coihaique
# Processing Record 152 | Grimshaw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=grimshaw
# Processing Record 153 | Berlevåg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=berlevag
# City not found. Skipping...
# Processing Record 154 | Upington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=upington
# Processing Record 155 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=carnarvon
# Processing Record 156 | Primorsko-Akhtarsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=primorsko-akhtarsk
# Processing Record 157 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=east%20london
# Processing Record 158 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=arraial%20do%20cabo
# City not found. Skipping...
# Processing Record 159 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tuatapere
# Processing Record 160 | Bharatpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bharatpur
# Processing Record 161 | Springbok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=springbok
# Processing Record 162 | Doembang Nangbuat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=doembang%20nangbuat
# Processing Record 163 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=lompoc
# Processing Record 164 | Hong Kong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=victoria
# Processing Record 165 | Manhattan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=manhattan
# Processing Record 166 | Nadvoitsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=nadvoitsy
# Processing Record 167 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tiksi
# Processing Record 168 | Vyaz'ma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=vyazma
# Processing Record 169 | Porto-Novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=porto%20novo
# Processing Record 170 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=clyde%20river
# Processing Record 171 | Beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=beloha
# Processing Record 172 | Newport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=newport
# Processing Record 173 | Woodend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=woodend
# Processing Record 174 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=poum
# Processing Record 175 | Normandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=normandin
# Processing Record 176 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=mayo
# Processing Record 177 | Mopipi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=mopipi
# Processing Record 178 | Noboribetsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=noboribetsu
# Processing Record 179 | Bredy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bredy
# Processing Record 180 | Yarmolyntsi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=yarmolyntsi
# Processing Record 181 | Edson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=edson
# City not found. Skipping...
# Processing Record 182 | Palu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=palu
# Processing Record 183 | Blythe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=blythe
# Processing Record 184 | Tshikapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tshikapa
# City not found. Skipping...
# Processing Record 185 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=zhigansk
# Processing Record 186 | Kroya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kroya
# Processing Record 187 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=khatanga
# Processing Record 188 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bandarbeyla
# Processing Record 189 | Storforshei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=storforshei
# Processing Record 190 | Rio Branco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=rio%20branco
# City not found. Skipping...
# Processing Record 191 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tasiilaq
# Processing Record 192 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=vila%20velha
# Processing Record 193 | Chino Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=chino%20valley
# Processing Record 194 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=saint%20anthony
# Processing Record 195 | Nosy Varika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=nosy%20varika
# Processing Record 196 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=shimoda
# Processing Record 197 | Bereket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=gazanjyk
# Processing Record 198 | Manacor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=manacor
# Processing Record 199 | Shawnee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=shawnee
# Processing Record 200 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=saint-augustin
# Processing Record 201 | Tazmalt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tazmalt
# Processing Record 202 | Mrkonjić Grad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=mrkonjic%20grad
# Processing Record 203 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=cabo%20san%20lucas
# Processing Record 204 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=egvekinot
# Processing Record 205 | Bitlis Province
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bitlis
# Processing Record 206 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ostrovnoy
# Processing Record 207 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=hasaki
# Processing Record 208 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=necochea
# Processing Record 209 | Galveston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=galveston
# Processing Record 210 | Leer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ler
# Processing Record 211 | El Alto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=el%20alto
# City not found. Skipping...
# Processing Record 212 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kavaratti
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 213 | Bongandanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bongandanga
# Processing Record 214 | Macultepec
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=macultepec
# Processing Record 215 | Carrickfergus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=carrickfergus
# Processing Record 216 | Praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=praia
# Processing Record 217 | Bahía Blanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bahia%20blanca
# Processing Record 218 | Vung Tau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=vung%20tau
# Processing Record 219 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bubaque
# Processing Record 220 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=pevek
# City not found. Skipping...
# Processing Record 221 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kamenka
# Processing Record 222 | Ndélé
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ndele
# Processing Record 223 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=srednekolymsk
# Processing Record 224 | Lancaster
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=lancaster
# Processing Record 225 | Urengoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=urengoy
# Processing Record 226 | Esmeraldas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=esmeraldas
# Processing Record 227 | Deputatsky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=deputatskiy
# Processing Record 228 | Narasannapeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=narasannapeta
# Processing Record 229 | Iwanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=iwanai
# Processing Record 230 | Kautokeino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kautokeino
# Processing Record 231 | Santa Ana de Yusguare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=santa%20ana%20de%20yusguare
# Processing Record 232 | Nizhniy Baskunchak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=nizhniy%20baskunchak
# Processing Record 233 | Carlyle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=carlyle
# Processing Record 234 | Linxia Chengguanzhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=linxia
# Processing Record 235 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=pisco
# Processing Record 236 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=portland
# Processing Record 237 | Jimeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=jimeta
# Processing Record 238 | Parrita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=parrita
# Processing Record 239 | Cocorit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=cocorit
# Processing Record 240 | Tortolì
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tortoli
# City not found. Skipping...
# Processing Record 241 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ponta%20delgada
# Processing Record 242 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ilulissat
# Processing Record 243 | Sept-Îles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=sept-iles
# Processing Record 244 | Jijiga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=jijiga
# Processing Record 245 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=chokurdakh
# City not found. Skipping...
# Processing Record 246 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=san%20cristobal
# Processing Record 247 | Funtua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=funtua
# Processing Record 248 | Rapid Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=rapid%20valley
# Processing Record 249 | Bac Lieu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bac%20lieu
# Processing Record 250 | Bumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bumba
# Processing Record 251 | Skibbereen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=skibbereen
# Processing Record 252 | Tyrma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tyrma
# Processing Record 253 | Magdagachi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=magdagachi
# Processing Record 254 | Aban
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=aban
# Processing Record 255 | Vardø
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=vardo
# Processing Record 256 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bethel
# Processing Record 257 | Kharhiāl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kharhial
# Processing Record 258 | Port Hawkesbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=port%20hawkesbury
# Processing Record 259 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=mount%20isa
# Processing Record 260 | Jardim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=jardim
# City not found. Skipping...
# Processing Record 261 | Mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=mackay
# Processing Record 262 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=gamba
# Processing Record 263 | Saint-François
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=saint-francois
# Processing Record 264 | Mpulungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=mpulungu
# Processing Record 265 | Voznesen'ye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=voznesenye
# Processing Record 266 | Westerland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=westerland
# Processing Record 267 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=laguna
# Processing Record 268 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=provideniya
# Processing Record 269 | Filingué
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=filingue
# Processing Record 270 | Payo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=payo
# Processing Record 271 | São João da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=sao%20joao%20da%20barra
# Processing Record 272 | Shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=shelburne
# Processing Record 273 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=longyearbyen
# Processing Record 274 | Beipiao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=beipiao
# Processing Record 275 | Vrangel'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=vrangel
# Processing Record 276 | Antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=antofagasta
# Processing Record 277 | Samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=samarai
# Processing Record 278 | Plettenberg Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=plettenberg%20bay
# Processing Record 279 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=faanui
# Processing Record 280 | Patancheru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=patancheru
# Processing Record 281 | Rambha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=rambha
# Processing Record 282 | Rosetta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=rosetta
# Processing Record 283 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=fairbanks
# Processing Record 284 | Kaa-Khem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kaa-khem
# Processing Record 285 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=cockburn%20town
# Processing Record 286 | Nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=nabire
# Processing Record 287 | Ha Giang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ha%20giang
# Processing Record 288 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=salalah
# Processing Record 289 | Jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=jalu
# Processing Record 290 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tautira
# Processing Record 291 | Tagusao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tagusao
# Processing Record 292 | Dinguiraye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=dinguiraye
# Processing Record 293 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=sur
# Processing Record 294 | Bristol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bristol
# Processing Record 295 | La Seyne-sur-Mer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=la%20seyne-sur-mer
# Processing Record 296 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tessalit
# Processing Record 297 | Dapaong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=dapaong
# Processing Record 298 | Babīna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=babina
# Processing Record 299 | Sosnovo-Ozerskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=sosnovo-ozerskoye
# Processing Record 300 | Havre-St-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=havre-saint-pierre
# Processing Record 301 | Byron Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=byron%20bay
# Processing Record 302 | Shestakovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=shestakovo
# Processing Record 303 | Sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=sorong
# Processing Record 304 | Douglas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=douglas
# Processing Record 305 | Roura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=roura
# Processing Record 306 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=faya
# Processing Record 307 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=geraldton
# Processing Record 308 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=rawson
# Processing Record 309 | Kichera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kichera
# Processing Record 310 | Hervey Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=hervey%20bay
# Processing Record 311 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=vestmannaeyjar
# Processing Record 312 | Khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=khani
# Processing Record 313 | Yanam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=yanam
# Processing Record 314 | Östersund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ostersund
# Processing Record 315 | Basco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=basco
# City not found. Skipping...
# Processing Record 316 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=buala
# Processing Record 317 | Ustupo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ustupo
# Processing Record 318 | Port Augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=port%20augusta
# Processing Record 319 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=padang
# Processing Record 320 | Siocon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=siocon
# Processing Record 321 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=port%20blair
# Processing Record 322 | Juneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=juneau
# Processing Record 323 | Sorochinsk
# ...
# Processing Record 484 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=hamilton
# Processing Record 485 | Tampilisan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tampilisan
# City not found. Skipping...
# Processing Record 486 | São Fidélis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=sao%20fidelis
# Processing Record 487 | Port Moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=port%20moresby
# Processing Record 488 | Inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=inuvik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 489 | Bogorodskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bogorodskoye
# Processing Record 490 | Phalaborwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=phalaborwa
# Processing Record 491 | Pemba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=pemba
# Processing Record 492 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=half%20moon%20bay
# Processing Record 493 | Shakiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=shakiso
# Processing Record 494 | Porbandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=porbandar
# Processing Record 495 | Óbidos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=obidos
# Processing Record 496 | Moranbah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=moranbah
# Processing Record 497 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=solnechnyy
# Processing Record 498 | Kasongo-Lunda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kasongo-lunda
# Processing Record 499 | Akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=akdepe
# Processing Record 500 | Srandakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=srandakan
# Processing Record 501 | Bam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bam
# Processing Record 502 | Wuwei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=wuwei
# Processing Record 503 | Camacupa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=camacupa
# Processing Record 504 | Japeri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=japeri
# Processing Record 505 | Safi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=asfi
# City not found. Skipping...
# Processing Record 506 | Winneba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=winneba
# Processing Record 507 | Waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=waipawa
# Processing Record 508 | Kailua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kailua
# Processing Record 509 | Acapulco de Juárez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=acapulco
# Processing Record 510 | Zhuangyuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=qixia
# Processing Record 511 | Derzhavīnsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=derzhavinsk
# Processing Record 512 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=arlit
# City not found. Skipping...
# Processing Record 513 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bonavista
# Processing Record 514 | Pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=pangody
# Processing Record 515 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=sioux%20lookout
# Processing Record 516 | Angoram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=angoram
# Processing Record 517 | Eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=eyl
# Processing Record 518 | Kunshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=yushan
# Processing Record 519 | Lamu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=lamu
# Processing Record 520 | Três Lagoas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=tres%20lagoas
# Processing Record 521 | Novomalorossiyskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=novomalorossiyskaya
# Processing Record 522 | Lichinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=lichinga
# Processing Record 523 | Pareora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=pareora
# Processing Record 524 | Itupiranga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=itupiranga
# Processing Record 525 | Arrondissement de Dole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=dole
# Processing Record 526 | Koslan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=koslan
# Processing Record 527 | Madison
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=madison
# Processing Record 528 | Laas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=lasa
# Processing Record 529 | Udachny
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=udachnyy
# Processing Record 530 | Bichena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bichena
# Processing Record 531 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=vanimo
# Processing Record 532 | Masaurhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=masaurhi
# Processing Record 533 | Şabyā
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=sabya
# Processing Record 534 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=broome
# Processing Record 535 | Simbahan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=simbahan
# Processing Record 536 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=port%20hedland
# Processing Record 537 | Finschhafen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=finschhafen
# Processing Record 538 | Trzebnica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=trzebnica
# Processing Record 539 | Haapiti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=haapiti
# Processing Record 540 | Chardara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=chardara
# Processing Record 541 | Sar-e Pul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=sar-e%20pul
# Processing Record 542 | Takaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=takaka
# Processing Record 543 | Guigue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=guigue
# Processing Record 544 | Leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=leh
# Processing Record 545 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=hambantota
# Processing Record 546 | Balabac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=balabac
# Processing Record 547 | Kajaani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kajaani
# Processing Record 548 | Eenhana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=eenhana
# City not found. Skipping...
# Processing Record 549 | Ngunguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ngunguru
# Processing Record 550 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=raudeberg
# Processing Record 551 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=comodoro%20rivadavia
# Processing Record 552 | Wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=wanning
# Processing Record 553 | Mongo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=mongo
# City not found. Skipping...
# Processing Record 554 | Hurricane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=hurricane
# Processing Record 555 | Pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=pangkalanbuun
# Processing Record 556 | Nārnaund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=narnaund
# Processing Record 557 | General Roca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=general%20roca
# Processing Record 558 | Sakakah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=sakakah
# Processing Record 559 | Khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=khasan
# Processing Record 560 | Bestöbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bestobe
# Processing Record 561 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=alice%20springs
# City not found. Skipping...
# Processing Record 562 | Rubiera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=rubiera
# Processing Record 563 | Linköping
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=linkoping
# Processing Record 564 | Concordia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=concordia
# Processing Record 565 | Oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=oranjemund
# Processing Record 566 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=chapais
# Processing Record 567 | Ginda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ginda
# Processing Record 568 | Verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=verkhoyansk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 569 | Palekastro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=palaikastron
# Processing Record 570 | Gillette
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=gillette
# City not found. Skipping...
# Processing Record 571 | Santa Gertrudes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=santa%20gertrudes
# Processing Record 572 | Gizo Government Station
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=gizo
# Processing Record 573 | Bayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=bayan
# Processing Record 574 | Gebre Guracha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=gebre%20guracha
# Processing Record 575 | Shelopugino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=shelopugino
# Processing Record 576 | Kushima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=kushima
# Processing Record 577 | Ulety
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=ulety
# Processing Record 578 | Puerto Escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=puerto%20escondido
# Processing Record 579 | Shumikha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=shumikha
# Processing Record 580 | Verkhnyaya Toyma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=verkhnyaya%20toyma
# Processing Record 581 | Coolum Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=coolum%20beach
# Processing Record 582 | Isiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=isiro
# Processing Record 583 | Baruun-Urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=baruun-urt
# Processing Record 584 | Inzer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=inzer
# Processing Record 585 | Karasjok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=karasjok
# Processing Record 586 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=anadyr
# Processing Record 587 | Owando
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=owando
# Processing Record 588 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=nanortalik
# Processing Record 589 | Honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=honiara
# Processing Record 590 | Roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48cd2f4c6e1cc4ac15520e0f752a9eb5&q=roald
# City not found. Skipping...

# %%
# Create a dictonary with the lists generated
weatherpy_dictionary = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dictionary)

# Display count of weather data values 
weather_data.count()
# Out:
# City          590
# Cloudiness    590
# Country       590
# Date          590
# Humidity      590
# Lat           590
# Lng           590
# Max Temp      590
# Wind Speed    590
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame

weather_data.to_csv('../output_data/weather_data.csv')
# Export the City_Data into a csv
weather_data.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Upernavik         100      GL  1604937981        81  72.79  -56.15
# 1       Albany           1      US  1604937967        81  42.60  -73.97
# 2       Palana          55      RU  1604938083        94  59.12  159.97
# 3  George Town          20      MY  1604937836        94   5.41  100.34
# 4    Busselton          57      AU  1604937962        69 -33.65  115.33
#
#    Max Temp  Wind Speed
# 0     -0.13        9.73
# 1     63.00        3.36
# 2     19.18        7.14
# 3     78.80        3.36
# 4     54.00       17.83

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../Output_data/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../Output_data/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../Output_data/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../Output_data/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
